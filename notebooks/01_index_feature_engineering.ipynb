# %% [markdown]
# ### Checking the performance of CSV v/s parquet formats

# %%
import pandas as pd
from pathlib import Path

DATA_PATH_CSV = Path("../data/processed/index/master/nifty50_index_master_2016_2026.csv")

df = pd.read_csv(DATA_PATH_CSV)

df.sort_values("trade_date")
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield  trade_date
# 0                2613.91  21.53  3.19       1.45  2016-01-01
# 25               5897.08  21.07  3.13       1.48  2016-01-04
# 34               5948.51  21.05  3.12       1.49  2016-01-05
# 42               6722.17  20.93  3.10       1.49  2016-01-06
# 49               7803.21  20.47  3.04       1.53  2016-01-07
# ...                  ...    ...   ...        ...         ...
# 2511            36735.38  22.25  3.46       1.23  2026-02-24
# 2512            31084.17  22.30  3.46       1.22  2026-02-25
# 2513            33155.50  22.31  3.47       1.22  2026-02-26
# 2515            38634.68  22.03  3.42       1.24  2026-02-27
# 2481            41306.37  21.76  3.38       1.25  2026-03-02
#
# [2519 rows x 13 columns]

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path("../data/processed/index/parquet/nifty50_index_master_2016_2026.parquet")
df = pd.read_parquet(DATA_PATH)

df.sort_values("trade_date")
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date
# 0                2613.91  21.53  3.19       1.45 2016-01-01
# 25               5897.08  21.07  3.13       1.48 2016-01-04
# 34               5948.51  21.05  3.12       1.49 2016-01-05
# 42               6722.17  20.93  3.10       1.49 2016-01-06
# 49               7803.21  20.47  3.04       1.53 2016-01-07
# ...                  ...    ...   ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24
# 2512            31084.17  22.30  3.46       1.22 2026-02-25
# 2513            33155.50  22.31  3.47       1.22 2026-02-26
# 2515            38634.68  22.03  3.42       1.24 2026-02-27
# 2481            41306.37  21.76  3.38       1.25 2026-03-02
#
# [2519 rows x 13 columns]

# %% [markdown]
# <b>Note:</b><i>From above example we can't see the difference between csv & parquet. But, <b>Parquet is more faster than csv</b> (we can see the clear difference in data of larger files. for ex. equity master dataset (having rows 4.2+ M))</i>

# %% [markdown]
# ### <b>Note:</b> All the above data is sorted in accending order by trade_date as we will work on the features that are heavily dependes on Dates

# %% [markdown]
# ### We need to sort the dates

# %%
df=df.sort_values("trade_date")

# %%
df
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date
# 0                2613.91  21.53  3.19       1.45 2016-01-01
# 25               5897.08  21.07  3.13       1.48 2016-01-04
# 34               5948.51  21.05  3.12       1.49 2016-01-05
# 42               6722.17  20.93  3.10       1.49 2016-01-06
# 49               7803.21  20.47  3.04       1.53 2016-01-07
# ...                  ...    ...   ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24
# 2512            31084.17  22.30  3.46       1.22 2026-02-25
# 2513            33155.50  22.31  3.47       1.22 2026-02-26
# 2515            38634.68  22.03  3.42       1.24 2026-02-27
# 2481            41306.37  21.76  3.38       1.25 2026-03-02
#
# [2519 rows x 13 columns]

# %% [markdown]
# ## Daily Return

# %%
df["return_1d"] = df["closing_index_value"].pct_change()
df
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date  return_1d
# 0                2613.91  21.53  3.19       1.45 2016-01-01        NaN
# 25               5897.08  21.07  3.13       1.48 2016-01-04  -0.021587
# 34               5948.51  21.05  3.12       1.49 2016-01-05  -0.000854
# 42               6722.17  20.93  3.10       1.49 2016-01-06  -0.005607
# 49               7803.21  20.47  3.04       1.53 2016-01-07  -0.022310
# ...                  ...    ...   ...        ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24  -0.011214
# 2512            31084.17  22.30  3.46       1.22 2026-02-25   0.002275
# 2513            33155.50  22.31  3.47       1.22 2026-02-26   0.000551
# 2515            38634.68  22.03  3.42       1.24 2026-02-27  -0.012468
# 2481            41306.37  21.76  3.38       1.25 2026-03-02  -0.012429
#
# [2519 rows x 14 columns]

# %% [markdown]
# pct_change() calculates the percentage change between the current value and the previous value.</br>
# Return=(Current Price−Previous Price​)/Previous Price</br>
# If the Result is 0.05 then the returns are 0.05*100 = 5% High from last closing

# %% [markdown]
# ## Weekly Momentum

# %%
df["return_5d"] = df["closing_index_value"].pct_change(5)
df
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date  return_1d  \
# 0                2613.91  21.53  3.19       1.45 2016-01-01        NaN
# 25               5897.08  21.07  3.13       1.48 2016-01-04  -0.021587
# 34               5948.51  21.05  3.12       1.49 2016-01-05  -0.000854
# 42               6722.17  20.93  3.10       1.49 2016-01-06  -0.005607
# 49               7803.21  20.47  3.04       1.53 2016-01-07  -0.022310
# ...                  ...    ...   ...        ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24  -0.011214
# 2512            31084.17  22.30  3.46       1.22 2026-02-25   0.002275
# 2513            33155.50  22.31  3.47       1.22 2026-02-26   0.000551
# 2515            38634.68  22.03  3.42       1.24 2026-02-27  -0.012468
# 2481            41306.37  21.76  3.38       1.25 2026-03-02  -0.012429
#
#       return_5d
# 0           NaN
# 25          NaN
# 34          NaN
# 42          NaN
# 49          NaN
# ...         ...
# 2511  -0.011691
# 2512  -0.013046
# 2513   0.001658
# 2515  -0.015353
# 2481  -0.032952
#
# [2519 rows x 15 columns]

# %% [markdown]
# ## Monthly Momentum

# %%
df["return_20d"] = df["closing_index_value"].pct_change(20)
df
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date  return_1d  \
# 0                2613.91  21.53  3.19       1.45 2016-01-01        NaN
# 25               5897.08  21.07  3.13       1.48 2016-01-04  -0.021587
# 34               5948.51  21.05  3.12       1.49 2016-01-05  -0.000854
# 42               6722.17  20.93  3.10       1.49 2016-01-06  -0.005607
# 49               7803.21  20.47  3.04       1.53 2016-01-07  -0.022310
# ...                  ...    ...   ...        ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24  -0.011214
# 2512            31084.17  22.30  3.46       1.22 2026-02-25   0.002275
# 2513            33155.50  22.31  3.47       1.22 2026-02-26   0.000551
# 2515            38634.68  22.03  3.42       1.24 2026-02-27  -0.012468
# 2481            41306.37  21.76  3.38       1.25 2026-03-02  -0.012429
#
#       return_5d  return_20d
# 0           NaN         NaN
# 25          NaN         NaN
# 34          NaN         NaN
# 42          NaN         NaN
# 49          NaN         NaN
# ...         ...         ...
# 2511  -0.011691    0.003232
# 2512  -0.013046    0.002502
# 2513   0.001658    0.006947
# 2515  -0.015353    0.014227
# 2481  -0.032952   -0.008877
#
# [2519 rows x 16 columns]

# %% [markdown]
# ## Rolling Volatility

# %%
df["volatility_20d"] = df["return_1d"].rolling(20).std()
df
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date  return_1d  \
# 0                2613.91  21.53  3.19       1.45 2016-01-01        NaN
# 25               5897.08  21.07  3.13       1.48 2016-01-04  -0.021587
# 34               5948.51  21.05  3.12       1.49 2016-01-05  -0.000854
# 42               6722.17  20.93  3.10       1.49 2016-01-06  -0.005607
# 49               7803.21  20.47  3.04       1.53 2016-01-07  -0.022310
# ...                  ...    ...   ...        ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24  -0.011214
# 2512            31084.17  22.30  3.46       1.22 2026-02-25   0.002275
# 2513            33155.50  22.31  3.47       1.22 2026-02-26   0.000551
# 2515            38634.68  22.03  3.42       1.24 2026-02-27  -0.012468
# 2481            41306.37  21.76  3.38       1.25 2026-03-02  -0.012429
#
#       return_5d  return_20d  volatility_20d
# 0           NaN         NaN             NaN
# 25          NaN         NaN             NaN
# 34          NaN         NaN             NaN
# 42          NaN         NaN             NaN
# 49          NaN         NaN             NaN
# ...         ...         ...             ...
# 2511  -0.011691    0.003232        0.010048
# 2512  -0.013046    0.002502        0.010038
# 2513   0.001658    0.006947        0.009993
# 2515  -0.015353    0.014227        0.009354
# 2481  -0.032952   -0.008877        0.009494
#
# [2519 rows x 17 columns]

# %% [markdown]
# moving window of 20 rows (20 days)</br>
# looks at the previous 20 days of returns_1d</br>
# std() calculates the standard deviation of the values inside the window</br>
# In simple words, How much the market has been fluctuating over the last 20 days</br>
# Higher std → more volatile market</br>
# Lower std → stable market</br>
# | Volatility (`volatility_20d`) | Approx %    | Market Type | Meaning                          |
# | ----------------------------- | ----------- | ----------- | -------------------------------- |
# | **< 0.007**                   | < 0.7%      | Low         | Stable / trending market         |
# | **0.007 – 0.015**             | 0.7% – 1.5% | Medium      | Normal market movement           |
# | **> 0.015**                   | > 1.5%      | High        | Panic / crash / highly uncertain |

# %% [markdown]
# ## Drawdown

# %%
rolling_max = df["closing_index_value"].cummax()
df["drawdown"] = df["closing_index_value"] / rolling_max - 1
df
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date  return_1d  \
# 0                2613.91  21.53  3.19       1.45 2016-01-01        NaN
# 25               5897.08  21.07  3.13       1.48 2016-01-04  -0.021587
# 34               5948.51  21.05  3.12       1.49 2016-01-05  -0.000854
# 42               6722.17  20.93  3.10       1.49 2016-01-06  -0.005607
# 49               7803.21  20.47  3.04       1.53 2016-01-07  -0.022310
# ...                  ...    ...   ...        ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24  -0.011214
# 2512            31084.17  22.30  3.46       1.22 2026-02-25   0.002275
# 2513            33155.50  22.31  3.47       1.22 2026-02-26   0.000551
# 2515            38634.68  22.03  3.42       1.24 2026-02-27  -0.012468
# 2481            41306.37  21.76  3.38       1.25 2026-03-02  -0.012429
#
#       return_5d  return_20d  volatility_20d  drawdown
# 0           NaN         NaN             NaN  0.000000
# 25          NaN         NaN             NaN -0.021587
# 34          NaN         NaN             NaN -0.022422
# 42          NaN         NaN             NaN -0.027903
# 49          NaN         NaN             NaN -0.049591
# ...         ...         ...             ...       ...
# 2511  -0.011691    0.003232        0.010048 -0.034332
# 2512  -0.013046    0.002502        0.010038 -0.032134
# 2513   0.001658    0.006947        0.009993 -0.031601
# 2515  -0.015353    0.014227        0.009354 -0.043675
# 2481  -0.032952   -0.008877        0.009494 -0.055561
#
# [2519 rows x 18 columns]

# %% [markdown]
# cummax() means cumulative maximum</br>
# (highest value the index has reached so far)</br>
# Drawdown = (Current Price​)/(Peak Price) - 1</br>
# how far the price has fallen from its highest point</br>
# If drawdown is -0.028 then -2.8% drawdown (Meaning price is 2.8% below its peak)

# %% [markdown]
# ## Volume Momentum

# %%
df["volume_change"] = df["volume"].pct_change(5)
df.head(6)
# Out:
#    index_name  open_index_value  high_index_value  low_index_value  \
# 0    NIFTY 50           7938.45           7972.55          7909.80
# 25   NIFTY 50           7924.55           7937.55          7781.10
# 34   NIFTY 50           7828.40           7831.20          7763.25
# 42   NIFTY 50           7788.05           7800.95          7721.20
# 49   NIFTY 50           7673.35           7674.95          7556.60
# 57   NIFTY 50           7611.65           7634.10          7581.05
#
#     closing_index_value  points_change  change(%)     volume  \
# 0               7963.20          16.85       0.21   64843836
# 25              7791.30        -171.90      -2.16  138864905
# 34              7784.65          -6.65      -0.09  149672973
# 42              7741.00         -43.65      -0.56  151715828
# 49              7568.30        -172.70      -2.23  194732861
# 57              7601.35          33.05       0.44  162348690
#
#     turnover_(rs._cr.)    p/e   p/b  div_yield trade_date  return_1d  \
# 0              2613.91  21.53  3.19       1.45 2016-01-01        NaN
# 25             5897.08  21.07  3.13       1.48 2016-01-04  -0.021587
# 34             5948.51  21.05  3.12       1.49 2016-01-05  -0.000854
# 42             6722.17  20.93  3.10       1.49 2016-01-06  -0.005607
# 49             7803.21  20.47  3.04       1.53 2016-01-07  -0.022310
# 57             6753.57  20.56  3.05       1.52 2016-01-08   0.004367
#
#     return_5d  return_20d  volatility_20d  drawdown  volume_change
# 0         NaN         NaN             NaN  0.000000            NaN
# 25        NaN         NaN             NaN -0.021587            NaN
# 34        NaN         NaN             NaN -0.022422            NaN
# 42        NaN         NaN             NaN -0.027903            NaN
# 49        NaN         NaN             NaN -0.049591            NaN
# 57   -0.04544         NaN             NaN -0.045440       1.503687

# %% [markdown]
# ## Save Features (Partitioned Parquet)

# %%
df["year"] = df["trade_date"].dt.year
df
# Out:
#      index_name  open_index_value  high_index_value  low_index_value  \
# 0      NIFTY 50           7938.45           7972.55          7909.80
# 25     NIFTY 50           7924.55           7937.55          7781.10
# 34     NIFTY 50           7828.40           7831.20          7763.25
# 42     NIFTY 50           7788.05           7800.95          7721.20
# 49     NIFTY 50           7673.35           7674.95          7556.60
# ...         ...               ...               ...              ...
# 2511   NIFTY 50          25641.80          25641.80         25327.60
# 2512   NIFTY 50          25512.60          25652.60         25428.20
# 2513   NIFTY 50          25556.30          25572.95         25400.95
# 2515   NIFTY 50          25459.85          25476.40         25141.30
# 2481   NIFTY 50          24659.25          24989.35         24603.50
#
#       closing_index_value  points_change  change(%)     volume  \
# 0                 7963.20          16.85       0.21   64843836
# 25                7791.30        -171.90      -2.16  138864905
# 34                7784.65          -6.65      -0.09  149672973
# 42                7741.00         -43.65      -0.56  151715828
# 49                7568.30        -172.70      -2.23  194732861
# ...                   ...            ...        ...        ...
# 2511             25424.65        -288.35      -1.12  439068188
# 2512             25482.50          57.85       0.23  414215742
# 2513             25496.55          14.05       0.06  405219244
# 2515             25178.65        -317.90      -1.25  438924282
# 2481             24865.70        -312.95      -1.24  519228821
#
#       turnover_(rs._cr.)    p/e   p/b  div_yield trade_date  return_1d  \
# 0                2613.91  21.53  3.19       1.45 2016-01-01        NaN
# 25               5897.08  21.07  3.13       1.48 2016-01-04  -0.021587
# 34               5948.51  21.05  3.12       1.49 2016-01-05  -0.000854
# 42               6722.17  20.93  3.10       1.49 2016-01-06  -0.005607
# 49               7803.21  20.47  3.04       1.53 2016-01-07  -0.022310
# ...                  ...    ...   ...        ...        ...        ...
# 2511            36735.38  22.25  3.46       1.23 2026-02-24  -0.011214
# 2512            31084.17  22.30  3.46       1.22 2026-02-25   0.002275
# 2513            33155.50  22.31  3.47       1.22 2026-02-26   0.000551
# 2515            38634.68  22.03  3.42       1.24 2026-02-27  -0.012468
# 2481            41306.37  21.76  3.38       1.25 2026-03-02  -0.012429
#
#       return_5d  return_20d  volatility_20d  drawdown  volume_change  year
# 0           NaN         NaN             NaN  0.000000            NaN  2016
# 25          NaN         NaN             NaN -0.021587            NaN  2016
# 34          NaN         NaN             NaN -0.022422            NaN  2016
# 42          NaN         NaN             NaN -0.027903            NaN  2016
# 49          NaN         NaN             NaN -0.049591            NaN  2016
# ...         ...         ...             ...       ...            ...   ...
# 2511  -0.011691    0.003232        0.010048 -0.034332       0.160217  2026
# 2512  -0.013046    0.002502        0.010038 -0.032134       0.033453  2026
# 2513   0.001658    0.006947        0.009993 -0.031601       0.214472  2026
# 2515  -0.015353    0.014227        0.009354 -0.043675       0.418751  2026
# 2481  -0.032952   -0.008877        0.009494 -0.055561       0.300882  2026
#
# [2519 rows x 20 columns]

# %%
import sys

# Add project root directory to sys.path
sys.path.append(str(Path().resolve().parents[0]))

# importing get_logger function from scripts.logger
from scripts.logger import get_logger

logger = get_logger(__name__)

output_path = Path("../data/features/index")

# Create index if not exists
if not output_path.exists():
    output_path.mkdir(parents=True, exist_ok=True)
    logger.info(f"Created directory: {output_path}")
else:
    logger.info(f"Directory already exisits:{output_path}")

years = df["year"].unique()

for year in years:
    try:
    
        df_year = df[df["year"] == year]
        
        file_path = output_path / f"index_features_{year}.parquet"

        # Check if parquet already exists
        if file_path.exists():
            logger.info(f"File already exists for year {year}: {file_path}")
        else:
            df_year.to_parquet(file_path, index=False)
            logger.info(f"Parquet file created for year {year}: {file_path}")
    
    except Exception as e:
        logger.error(f"Error while creating parquet for year {year}: {e}")
